# %% [markdown]
# ## Bài 1

# %%
n = int(input())
print(n*2)

# %% [markdown]
# ## Bài 2

# %%
a = float(input("Chiều rộng "))
b = float(input("Chiều dài "))
pi = 3.14
r = a/2
dtcn = a*b
dtht = pi*r*r
s = dtcn - dtht
print(round(s, 2))
# Out:
# 2.86

# %% [markdown]
# ## Bài 3

# %%
c = input()
if c.isupper():
    print("Chữ thường tương ứng:", c.lower())
else:
    print("Chữ hoa tương ứng:", c.upper())
# Out:
# Chữ thường tương ứng: a

# %% [markdown]
# ## Bài 4

# %%
c = input()
if c.isalpha():
    print(c, "là kí tự alphabet")
else:
    print(c, "không phải là kí tự alphabet")
# Out:
#  không phải là kí tự alphabet

# %% [markdown]
# ## Bài 5

# %%
c = input()
if c == 'A':
    print("Không có chữ đứng trước")
else:
    k = c.lower()
    tr = chr(ord(k) -1)
    print(tr)
# Out:
# a

# %% [markdown]
# ## Bài 6

# %%
a = float (input())
b = float (input())
c= float (input())
if a+b>c and a+c>b and b+c>a:
    p = (a+b+c)/2
    s= (p*(p-a)*(p-b)*(p-c))
    print(round(s,1))
else:
    print("Không phải ba cạnh của tam giác")
# Out:
# Không phải ba cạnh của tam giác

# %% [markdown]
# ## Bài 7

# %%
s = input()
if len(s) >=20:
    print("Kí tự thứ 5:", s[4])
    print("Kí tự thứ 9", s[8])
else:
    print("chuỗi chưa đủ 20 kí tự")

# %% [markdown]
# ## Bài 8

# %%
ten = input("Ten chu ho: ")
so_dien_cu = int(input("Chi so thanh truoc: "))
so_dien_moi = int(input("Chi so thanh nay: "))
so_dien = so_dien_moi - so_dien_cu
tien = 0
if so_dien <=50:
    tien = so_dien*1984 
elif so_dien <=100:
    tien = 50*1984 + (so_dien-50)*2050
elif so_dien <=200:
    tien = 50*1984 + 50*2050 + (so_dien-100)*2380
elif so_dien <= 300:
    tien =   50*1984 + 50*2050 + 50*2380 + (so_dien-150)*2998
elif so_dien <= 400:
    tien =  50*1984 + 50*2050 +50*2380 + 50*2998 + (so_dien-200)*3350     
elif so_dien >= 401:
    tien = 50*1984 + 50*2050 +50*2380 + 50*2998 + 50*3350+(so_dien-250)*3460

tien = tien * 1.08
print(ten)
print(f"Tien phai tra la:",{tien})
# Out:
# nguyen dinh dinh
# Tien phai tra la: {107136.0}
